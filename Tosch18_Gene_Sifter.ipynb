# %%
# Initialize environment
import pandas as pd
import numpy as np

path = "/Users/stephens/Desktop/COiN Plasticity Evolves/Turtle/"
source = path + "turtle_merged_metadata_normcpm.csv"
genes = "NPPs"

# %%
# read sifter lists
annoSifter = list(pd.read_csv(path+"turtle_anno_sifter.csv", header = None)[0])
geneSifter = list(pd.read_csv(path+"turtle_" + genes + "_sifter.csv", header = None)[0])

# %%
len(geneSifter)
# Out:
# 72

# %%
len(annoSifter)
# Out:
# 6

# %%
df = pd.read_csv(source, usecols = annoSifter + geneSifter)

# %%
df
# Out:
#                sample_id   region supercluster cluster  region_id  cluster_id  \
# 0     d3s01_TTTACACTATTA   cortex           PT     e03          1          40
# 1     d3s01_ATCATCGGACGA   cortex         pDVR     e22          1          55
# 2     d3s01_ATCCTAGTTCCC   cortex           PT     e06          1          43
# 3     d3s01_GACCTTCCGACG   cortex          aLC     e12          1          47
# 4     d3s01_TCATATTGTTAT   cortex           PT     e04          1          41
# ...                  ...      ...          ...     ...        ...         ...
# 5896  d7s08_AGCGGCTCTGAA  postCtx          pDC     e26          6          31
# 5897  d7s08_CGGGTGAGACAA  postCtx  MGE-PV-like     i13          6          19
# 5898  d7s08_ACAAGCGCGGGT  postCtx           MC     e30          6          21
# 5899  d7s08_CACGCTCCTTTA  postCtx          DMC     e37          6          28
# 5900  d7s08_GCGGCTCTGAAN  postCtx          pDC     e26          6          31
#
# ...

# %%
df.to_csv(path + "turtle_" + genes + "_normcpm.csv")
